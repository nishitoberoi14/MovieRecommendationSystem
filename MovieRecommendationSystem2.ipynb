# %% [markdown]
# # Collaborative Filtering Movie Recommendation

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Reading in movie data from CSV

# %%
movies_5000 = pd.read_csv('/content/drive/MyDrive/Dataset/tmdb_5000_movies.csv')

# %%
movies_5000.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26   880674609
# 3  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16  1084939099
# 4  [{"iso_3166_1": "US", "name": "United States o...   2012-03-07   284139100
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 2    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3    165.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 4    132.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                               John Carter           6.1        2124

# %%
movies_25M = pd.read_csv("/content/drive/MyDrive/Dataset/ml-25m/ml-25m/movies.csv")

# %%
movies_25M.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# 8                                       Action
# 9                    Action|Adventure|Thriller

# %% [markdown]
# Creating a cleaner title by removing the year

# %%
from os import remove
import re

def clean_title(title):
   clean_title = re.sub("[^a-zA-Z0-9]", " ", title)
   remove_year = clean_title[:-5].strip()
   return remove_year

# %%
movies_25M["clean_title"] = movies_25M["title"].apply(clean_title)

# %%
movies_25M.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres                  clean_title
# 0  Adventure|Animation|Children|Comedy|Fantasy                    Toy Story
# 1                   Adventure|Children|Fantasy                      Jumanji
# 2                               Comedy|Romance             Grumpier Old Men
# 3                         Comedy|Drama|Romance            Waiting to Exhale
# 4                                       Comedy  Father of the Bride Part II

# %%
movies_25M.drop('title', axis = 1, inplace = True)
movies_25M.head()
# Out:
#    movieId                                       genres  \
# 0        1  Adventure|Animation|Children|Comedy|Fantasy
# 1        2                   Adventure|Children|Fantasy
# 2        3                               Comedy|Romance
# 3        4                         Comedy|Drama|Romance
# 4        5                                       Comedy
#
#                    clean_title
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II

# %%
movies_5000 = movies_5000[['title']]
movies_5000.head()
# Out:
#                                       title
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter

# %% [markdown]
# Merging the 5K dataset with the 25M dataset

# %%
merged_dataset = pd.merge(movies_25M, movies_5000, left_on='clean_title', right_on='title', how='inner')
merged_dataset.drop('title', axis=1, inplace=True)

merged_dataset.head()
# Out:
#    movieId                                       genres       clean_title
# 0        1  Adventure|Animation|Children|Comedy|Fantasy         Toy Story
# 1       10                    Action|Adventure|Thriller         GoldenEye
# 2       14                                        Drama             Nixon
# 3       15                     Action|Adventure|Romance  Cutthroat Island
# 4       16                                  Crime|Drama            Casino

# %%
len(merged_dataset)
# Out:
# 3728

# %% [markdown]
# Data was lost when merging both datasets:
# 5000 - 3278 = 1272 (amount of data missing)

# %% [markdown]
# ###Using TFIDF vectorization technique to make each title as a numerical vector based on the words in the title

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(ngram_range=(1,2))
tfidf = vectorizer.fit_transform(merged_dataset['clean_title'])

# %% [markdown]
# When search for a title, the query is converted to its own vector which is then used to match with other similar vectors by using cosine similarity. Consine similarity finds the closest vectors by cosine angle

# %%
from sklearn.metrics.pairwise import cosine_similarity

def search(title):
  query_vec = vectorizer.transform([title])
  similarity = cosine_similarity(query_vec, tfidf).flatten()
  indices = np.argpartition(similarity, -5)[-5:]
  results = merged_dataset.iloc[indices][::-1]
  return results

# %% [markdown]
# Search bar widget to find movie

# %%
import ipywidgets as widgets
from IPython.display import display

input = widgets.Text(
    value = "Toy Story",
    description = "Movie Title: ",
    disabled = False
)
list = widgets.Output()

def on_type(data):
  with list:
    list.clear_output()
    title = data["new"]
    if len(title) > 5:
      display(search(title))

input.observe(on_type, names='value')
display(input, list)
# Out:
# Text(value='Toy Story', description='Movie Title: ')
# Output()

# %% [markdown]
# Reading in the review data from CSV

# %%
ratings_25M = pd.read_csv('/content/drive/MyDrive/Dataset/ml-25m/ml-25m/ratings.csv')

# %%
new_ratings = ratings_25M[ratings_25M['movieId'].isin(set(merged_dataset['movieId']))]

# %%
new_ratings.head()
# Out:
#     userId  movieId  rating   timestamp
# 0        1      296     5.0  1147880044
# 11       1     1653     4.0  1147868097
# 12       1     2011     2.5  1147868079
# 13       1     2012     2.5  1147868068
# 17       1     2573     4.0  1147878923

# %%
new_ratings.dtypes
# Out:
# userId         int64
# movieId        int64
# rating       float64
# timestamp      int64
# dtype: object

# %%
movie_id = 1

# %% [markdown]
# Preparing the review data by getting the people who liked similar movies

# %%
same_users = new_ratings[(new_ratings['movieId'] == movie_id) & (new_ratings["rating"] > 4)]["userId"].unique()

# %%
same_users
# Out:
# array([    36,     75,     86, ..., 162527, 162530, 162533])

# %%
same_user_recs = new_ratings[(new_ratings["userId"].isin(same_users)) & (new_ratings["rating"] > 4)]["movieId"]

# %%
same_user_recs
# Out:
# 5101            1
# 5105           34
# 5111          110
# 5114          150
# 5154          497
#             ...
# 24998813    33794
# 24998850    56782
# 24998876    78499
# 24998884    81591
# 24998888    88129
# Name: movieId, Length: 561974, dtype: int64

# %% [markdown]
# Extracting the movies that more than 10% of users recommended

# %%
same_user_recs = same_user_recs.value_counts() / len(same_users)
same_user_recs = same_user_recs[same_user_recs > .1]

# %%
same_user_recs
# Out:
# movieId
# 1        1.000000
# 356      0.370215
# 296      0.367295
# 3114     0.280648
# 1270     0.275020
# 2959     0.262649
# 110      0.239873
# 2028     0.231059
# 6377     0.228139
# 480      0.227980
# 2858     0.216724
# 588      0.216618
# 1136     0.213539
# 4306     0.203663
# 1291     0.197611
# 4226     0.192567
# 150      0.190231
# 1265     0.181736
# 3578     0.178604
# 1214     0.173772
# 1036     0.171702
# 1704     0.170746
# 79132    0.166817
# 541      0.166392
# 68954    0.159172
# 1200     0.154075
# 78499    0.152960
# 1089     0.152376
# 7361     0.145474
# 912      0.143244
# 33794    0.139368
# 34       0.130555
# 2329     0.123547
# 2997     0.116963
# 111      0.115530
# 50872    0.113990
# 590      0.113300
# 1208     0.112132
# 1387     0.111388
# 1219     0.109212
# 5989     0.108946
# 1961     0.105867
# 8368     0.105017
# 1259     0.104646
# 59315    0.104593
# 778      0.103902
# Name: count, dtype: float64

# %% [markdown]
# Find people who have rated movies and rated them highly. Finding the percentage of all users who recommended the movies

# %%
all_users = new_ratings[(new_ratings["movieId"]).isin(same_user_recs.index) & (new_ratings["rating"] > 4)]

# %%
all_users_recs = all_users["movieId"].value_counts() / len(all_users["userId"].unique())

# %%
all_users_recs
# Out:
# movieId
# 296      0.322034
# 356      0.266142
# 2959     0.245159
# 2858     0.189634
# 110      0.181985
# 4226     0.149271
# 2028     0.148799
# 79132    0.148626
# 1        0.141098
# 1136     0.138558
# 541      0.130093
# 3578     0.129943
# 1270     0.129651
# 1704     0.121935
# 7361     0.117920
# 1214     0.114706
# 1089     0.114002
# 480      0.112998
# 2329     0.107155
# 912      0.104750
# 1291     0.104593
# 150      0.102465
# 1200     0.093731
# 1208     0.093341
# 111      0.092427
# 1036     0.091888
# 1265     0.090367
# 4306     0.089910
# 778      0.084569
# 2997     0.083355
# 33794    0.082958
# 6377     0.081752
# 590      0.079287
# 588      0.076373
# 68954    0.073467
# 1219     0.068612
# 5989     0.067481
# 59315    0.061391
# 1961     0.060814
# 3114     0.060754
# 34       0.059084
# 1259     0.055330
# 8368     0.054776
# 1387     0.053690
# 50872    0.044243
# 78499    0.039741
# Name: count, dtype: float64

# %% [markdown]
# Find the percentages of users who are similar to us liked them and how much everyone liked them

# %%
rec_percentages = pd.concat([same_user_recs, all_users_recs], axis = 1)
rec_percentages.columns = ["similar", "all"]

# %%
rec_percentages
# Out:
#           similar       all
# movieId
# 1        1.000000  0.141098
# 356      0.370215  0.266142
# 296      0.367295  0.322034
# 3114     0.280648  0.060754
# 1270     0.275020  0.129651
# 2959     0.262649  0.245159
# 110      0.239873  0.181985
# 2028     0.231059  0.148799
# 6377     0.228139  0.081752
# 480      0.227980  0.112998
# 2858     0.216724  0.189634
# 588      0.216618  0.076373
# 1136     0.213539  0.138558
# 4306     0.203663  0.089910
# 1291     0.197611  0.104593
# 4226     0.192567  0.149271
# 150      0.190231  0.102465
# 1265     0.181736  0.090367
# 3578     0.178604  0.129943
# 1214     0.173772  0.114706
# 1036     0.171702  0.091888
# 1704     0.170746  0.121935
# 79132    0.166817  0.148626
# 541      0.166392  0.130093
# 68954    0.159172  0.073467
# 1200     0.154075  0.093731
# 78499    0.152960  0.039741
# 1089     0.152376  0.114002
# 7361     0.145474  0.117920
# 912      0.143244  0.104750
# 33794    0.139368  0.082958
# 34       0.130555  0.059084
# 2329     0.123547  0.107155
# 2997     0.116963  0.083355
# 111      0.115530  0.092427
# 50872    0.113990  0.044243
# 590      0.113300  0.079287
# 1208     0.112132  0.093341
# 1387     0.111388  0.053690
# 1219     0.109212  0.068612
# 5989     0.108946  0.067481
# 1961     0.105867  0.060814
# 8368     0.105017  0.054776
# 1259     0.104646  0.055330
# 59315    0.104593  0.061391
# 778      0.103902  0.084569

# %% [markdown]
# Make a ratio of the similar and general users and sort to find the largest since this would be the best niche recommendations

# %%
rec_percentages["score"] = rec_percentages["similar"] / rec_percentages["all"]

# %%
rec_percentages = rec_percentages.sort_values("score", ascending = False)

# %%
rec_percentages
# Out:
#           similar       all     score
# movieId
# 1        1.000000  0.141098  7.087284
# 3114     0.280648  0.060754  4.619406
# 78499    0.152960  0.039741  3.848910
# 588      0.216618  0.076373  2.836304
# 6377     0.228139  0.081752  2.790622
# 50872    0.113990  0.044243  2.576431
# 4306     0.203663  0.089910  2.265191
# 34       0.130555  0.059084  2.209666
# 68954    0.159172  0.073467  2.166583
# 1270     0.275020  0.129651  2.121230
# 1387     0.111388  0.053690  2.074665
# 480      0.227980  0.112998  2.017555
# 1265     0.181736  0.090367  2.011090
# 8368     0.105017  0.054776  1.917211
# 1259     0.104646  0.055330  1.891286
# 1291     0.197611  0.104593  1.889333
# 1036     0.171702  0.091888  1.868602
# 150      0.190231  0.102465  1.856539
# 1961     0.105867  0.060814  1.740828
# 59315    0.104593  0.061391  1.703716
# 33794    0.139368  0.082958  1.679982
# 1200     0.154075  0.093731  1.643806
# 5989     0.108946  0.067481  1.614466
# 1219     0.109212  0.068612  1.591718
# 2028     0.231059  0.148799  1.552830
# 1136     0.213539  0.138558  1.541147
# 1214     0.173772  0.114706  1.514935
# 590      0.113300  0.079287  1.428974
# 2997     0.116963  0.083355  1.403189
# 1704     0.170746  0.121935  1.400301
# 356      0.370215  0.266142  1.391044
# 3578     0.178604  0.129943  1.374474
# 912      0.143244  0.104750  1.367481
# 1089     0.152376  0.114002  1.336608
# 110      0.239873  0.181985  1.318090
# 4226     0.192567  0.149271  1.290052
# 541      0.166392  0.130093  1.279025
# 111      0.115530  0.092427  1.249954
# 7361     0.145474  0.117920  1.233667
# 778      0.103902  0.084569  1.228613
# 1208     0.112132  0.093341  1.201312
# 2329     0.123547  0.107155  1.152972
# 2858     0.216724  0.189634  1.142857
# 296      0.367295  0.322034  1.140547
# 79132    0.166817  0.148626  1.122391
# 2959     0.262649  0.245159  1.071344

# %%
rec_percentages.head(6).merge(merged_dataset, left_index = True, right_on="movieId")
# Out:
#        similar       all     score  movieId  \
# 0     1.000000  0.141098  7.087284        1
# 821   0.280648  0.060754  4.619406     3114
# 2568  0.152960  0.039741  3.848910    78499
# 153   0.216618  0.076373  2.836304      588
# 1498  0.228139  0.081752  2.790622     6377
# 2104  0.113990  0.044243  2.576431    50872
#
#                                                 genres   clean_title
# 0          Adventure|Animation|Children|Comedy|Fantasy     Toy Story
# 821        Adventure|Animation|Children|Comedy|Fantasy   Toy Story 2
# 2568  Adventure|Animation|Children|Comedy|Fantasy|IMAX   Toy Story 3
# 153        Adventure|Animation|Children|Comedy|Musical       Aladdin
# 1498               Adventure|Animation|Children|Comedy  Finding Nemo
# 2104                          Animation|Children|Drama   Ratatouille

# %% [markdown]
# This finds users similar to those who like the inputted movie and general user's recommendations. Recommendations where only 10% of users recommend. Then find how common recommendations and sorting score to find best recommendation

# %%
def find_same_movies(movie_id):
  same_users = new_ratings[(new_ratings['movieId'] == movie_id) & (new_ratings["rating"] > 4)]["userId"].unique()
  same_user_recs = new_ratings[(new_ratings["userId"].isin(same_users)) & (new_ratings["rating"] > 4)]["movieId"]

  same_user_recs = same_user_recs.value_counts() / len(same_users)
  same_user_recs = same_user_recs[same_user_recs > .1]

  all_users = new_ratings[(new_ratings["movieId"]).isin(same_user_recs.index) & (new_ratings["rating"] > 4)]
  all_users_recs = all_users["movieId"].value_counts() / len(all_users["userId"].unique())

  rec_percentages = pd.concat([same_user_recs, all_users_recs], axis = 1)
  rec_percentages.columns = ["similar", "all"]

  rec_percentages["score"] = rec_percentages["similar"] / rec_percentages["all"]

  rec_percentages = rec_percentages.sort_values("score", ascending = False)
  return rec_percentages.head(6).merge(merged_dataset, left_index = True, right_on="movieId")[["score", "clean_title", "genres"]]

# %% [markdown]
# Widget to input movie and get recommendations

# %%
movie_input = widgets.Text(
    value = "",
    description = "Movie Title:",
    disabled = False
)

rec_list = widgets.Output()

def on_type(data):
  with rec_list:
    rec_list.clear_output()
    title = data["new"]
    if len(title) > 5:
      results = search(title)
      movie_id = results.iloc[0]["movieId"]
      display(find_same_movies(movie_id))

movie_input.observe(on_type, names="value")
display(movie_input, rec_list)
# Out:
# Text(value='', description='Movie Title:')
# Output()
